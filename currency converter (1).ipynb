# %%
import tkinter as tk
from tkinter import *
from tkinter import ttk
from datetime import datetime
import requests
from PIL import ImageTk, Image
from tkinter import messagebox

root = tk.Tk()
root.geometry("600x270")
root.title("currncy converter")
root.iconbitmap('C:\\Users\\karne\\Downloads\\icon.ico')
root.maxsize(600, 270)
root.minsize(600, 270)
image = Image.open('C:\\Users\\karne\\Downloads\\currency.png')
zoom = 0.5
pixels_x, pixels_y = tuple([int(zoom * x) for x in image.size])
img = ImageTk.PhotoImage(image.resize((pixels_x, pixels_y)))
panel = Label(root, Image=img)
panel.place(x=190, y=35)


def show_data():
    amount = E1.get()
    from_currency = c1.get()
    to_currency = c2.get()
    url = 'http://api.currencylayer.com/live?access_key=4273d2c37f738367f08780b934ce7dda&format=1'

    if amount == '':
        messagebox.showerror("currency convrter", "please Fill the Amount")
    elif to_currency == '':
        messagebox.showerror("currency converter", "please Choose the currency")
    else:
        data = requests.get(uri).json()
        currnecy = from_currency.strip() + to_currency.strip()
        amount = int(amount)
        cc = data['quotes'][currency]
        cur_conv = cc * amount
        E2.insert(0, cur_conv)
        text.insert('end',
                    f'{amount} United State Dollar Equals{cur_conv} {to_currency} \n\n Last Time Update --- \t {datetime.now()}')


def clear():
    E1.delete(0, 'end')
    E2.delete(0, 'end')
    text.delete(1.0, 'end')


l1 = Label(root, text="USD Currency Converter Using Python", font=('verdana', '10', 'bold'))
l1.place(x=150, y=15)
amt = Label(root, text="Amount", font=('roboto', 10, 'bold'))
amt.place(x=20, y=15)
E1 = enter(root, width=20, borderwidth=1, font=('roboto', 10, 'bold'))
E1.place(x=20, y=40)
c1 = tk.stringVar()
c2 = tk.stringVar()
currencychoose1 = ttk.combobox(root, width=20, textvariable=c1, state='readonly', font=('verdana', 10, 'bold'))

currencychoose1['values'] = (
    'USD',
)
currencychoose1.place(x=300, y=40)
currencychoose1.current(0)
E2 = Entry(root, width=20, borderwidth=1, font=('roboto', 10, 'bold'))
E2.place(x=20, y=80)
currencychoose2 = ttl.combobox(root, width=20, textvariable=c2, state='readonly', font=('verdana', '10', 'bold'))
currencychoose2['values'] = ('ALL',
                             ' AFN',
                             ' ARS',
                             ' AWG',
                             ' AUD',
                             ' AZN',
                             ' BSD',
                             ' BBD',
                             ' BYN',
                             ' BZD',
                             ' BMD',
                             ' BOB',
                             ' BAM',
                             ' BWP',
                             ' BGN',
                             ' BND',
                             ' KHR',
                             ' CAD',
                             ' KYD',
                             ' UZS',
                             ' INR',
                             ' ZWD',)
currencychoose2.place(x=300, y=80)
currencychoose2.current()
text = Text(root, height=7, width=52, font=('verdana', '10', 'bold'))
text.place(x=100, y=120)
B = Button(root, text="search", command=show_data, font=('verdana', '10', 'bold'), borderwidth=2, bg="red", fg="white")
B.place(x=20, y=120)
cla = ear = Button(root, text="Clear", command=clear, font=('verdana', '10', 'bold'), borderwidth=2, bg="blue",
                   fg="white")
clear.place(x=20, y=170)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 19
#      17 pixels_x, pixels_y = tuple([int(zoom * x) for x in image.size])
#      18 img = ImageTk.PhotoImage(image.resize((pixels_x, pixels_y)))
# ---> 19 panel = Label(root, Image=img)
#      20 panel.place(x=190, y=35)
#      23 def show_data():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:3248, in Label.__init__(self, master, cnf, **kw)
#    3230 def __init__(self, master=None, cnf={}, **kw):
#    3231     """Construct a label widget with the parent MASTER.
#    3232
#    3233     STANDARD OPTIONS
#    (...)
#    3246
#    3247     """
# -> 3248     Widget.__init__(self, master, 'label', cnf, kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:2659, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2657 for k, v in classes:
#    2658     del cnf[k]
# -> 2659 self.tk.call(
#    2660     (widgetName, self._w) + extra + self._options(cnf))
#    2661 for k, v in classes:
#    2662     k.configure(self, v)
#
# TclError: unknown option "-Image"
