# %%
from tkinter import *
import tkinter as tk
from tkinter.scrolledtext import scrolledText
import random
from datetime import datetime
from tkinter import filedialog


def total_bills():
    mozito_price = 60
    cococola_price = 50
    thumbsup_price = 50
    redbull_price = 50
    roti_price = 10
    butter_naan_price = 30
    panneer_buttermasala_price = 300
    veg_biryani_price = 180
    chicken_biryani_price = 230
    mutton_biryani_price = 300

    mozito_q = mozito_qty.get()
    cococola_q = cococola_qty.get()
    thumbsup_q = thumbsup_qty.get()
    redbull_q = redbull_qty.get()

    roti_q = roti_qty.get()
    butter_naan_q = butter_naan_qty.get()
    panner_buttermasala-q = panner_buttermasala_qty.get()
    veg_biryani_q = veg_biryani_qty.get()
    chicken_biryani_q = chicken_biryani_qty.get()
    mutton_biryani_q = mutton_biryani.get()

    if mozito_var.get() == 0:
            mozito_q = 0
    else mozito_var.get() == 1 and mozito_qty.get() =="":
            messagebox.showerror("error","please fill the mozito quantity")
            mozito_q = 0
    if cococola_var.get() == 0:
            cococola_q = 0
    else cococola_var.get() == 1 and cococola_qty.get() =="":
            messagebox.showerror("error","please fill the cococola quantity")
            cococola_q = 0
    if thumbsup_var.get() == 0:
            thumbsup_q = 0
    else thumbsup_var.get() == 1 and thumbsup_qty.get() =="":
            messagebox.showerror("error","please fill the thumbsup quantity")
            thumbsup_q = 0
    if redbull_var.get() == 0:
            redbull_q = 0
    else redbull_var.get() == 1 and redbull_qty.get() =="":
            messagebox.showerror("error","please fill the redbull quantity")
            redbull_q = 0
    if roti_var.get() == 0:
            roti_q = 0
    else roti_var.get() == 1 and roti_qty.get() =="":
            messagebox.showerror("error","please fill the roti quantity")
            roti_q = 0
    if butter_naan_var.get() ==0:
            butter_naan_q = 0
    else butter_naan_var.get() == 1 and butter_naan_qty.get() =="":
            messagebox.showerror("error","please fill the butter_naan quantity")
            butter_naan_q = 0
    if paneer_buttermasala_var.get() == 0:
            paneer_buttermasala_q = 0
    else paneer_buttermasala_var.get() == 1 and paneer_buttermasala_qty.get() =="":
            messagebox.showerror("error","please fill the paneer_buttermasala quantity")
            paneer_buttermasala_q = 0
    if veg_biryani_var.get() == 0:
            veg_biryani_q = 0
    else veg_biryani_var.get() == 1 and veg_biryani_qty.get() =="":
            messagebox.showerror("error","please fill the veg_biryani quantity")
            veg_biryani_q =0
    if chicken_biryani_var.get() == 0:
            chicken_biryani_q = 0
    else chicken_biryani_var.get() == 1 and chicken_biryani_qty.get() =="":
            messagebox.showerror("error","please fill the chicken_biryani quantity")
            chicken_biryani_q =0
    if mutton_biryani_var.get() == 0:
            mutton_biryani_q = 0
    else mutton_biryani_var.get() == 1 and mutton_biryani_qty.get() =="":
            messagebox.showerror("error","please fill the mutton_biryani quantity")
            mutton_biryani_q = 0

    total_mozito_price = mozito_price * int(mozito_q)
    total_cocococla_price = cococola_price * int(cococola_q)
    total_thumbsup_price = thumbsup_price * int(thumbsup_q)
    total_redbull_price = redbull_price * int(redbull_q)

    total_drinks_cost = total_mozito_price + total_cococola_price + total_thumbsup_price + total_redbull_price
    if drinks_cost.get() != "":
            drinks_cost.delete(0,"end")
            drinks_cost.insert("end",total_drinks_cost)
    else:
            drinks_cost.insert("end",total_drinks_cost)

    total_roti_price = roti_price * int(roti_q)
    total_butter_naan_price = butter_naan_price * int(butter_naan_q)
    total_paneer_buttermasala_price = paneer_buttermasala_price * int(paneer_buttermasala_q)
    total_veg_biryani_price = veg_biryani_price * int(veg_biryani_q)
    total_chicken_biryani_price = chicken_biryani_price * int(chicken_biryani_q)
    total_mutton_biryani_price = mutton_biryani_price * int(mutton-biryani_q)

    total_food_cost = total_roti_price + total_butter_naan_price + total_panerr_buttermasala_price + total_veg_biryani_price + total_chicken_biryani_price + total_mutton_biryani_price
    if food_cost.get() !="":
            food_cost.delete(0,"end")
            food_cost.insert("end",total_food_cost)
    else:
            food_cost.insert("end",total_food_cost)


    if service_charge_cost.get() != "":
            service_charge_cost.delete(0,"end")
            service_charge_cost.insert(0,"10")
    else:
            service_charge_cost.insert(0,"10")

    fc = int(food_cost.get())
    dc = int(drinks_cost.get())

    total_paid_tax = fc+dc
    total_paid_tax = total_paid_tax * 8 / 100

    if paid_tax_cost != "":
            paid_tax_cost.delete(0,"end")
            paid_tax_cost.insert(0,total_paid_tax)
    else:
            paid_tax_cost.insert(0,total_paid_tax)


    total_sub_cost = fc+dc+int(service_charge_cost.get())
    if sub_total_cost.get() != "":
            sub_total_cost.delete(0,"end")
            sub_total_cost.insert(0,total_sub_cost)
    else:
            sub_total_cost.insert(0,total_sub_cost)

    if total_cost_cost.get() != "":
            total_cost_cost.delete(0,"end")
            total_cost_cost.insert(0,float(total_sub_cost + total-paid_tax))
    else:
            total_cost_cost.insert(0,float(total_sub_cost + total_paid_tax))
# Out:
#   Cell In[1], line 28
#     panner_buttermasala-q = panner_buttermasala_qty.get()
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
